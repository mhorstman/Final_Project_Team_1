# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
# bring in our Beverly Grove file

Beverly_Grove_df = pd.read_csv('Beverly_Grove_Cleaned.csv', index_col='PARCEL')
Beverly_Grove_df.head()
# Out:
#             Owned by Trust?  Owned by Business?          SITEADDRESS  \
# PARCEL
# 5085010022                0                   0  1030 S Dunsmuir Ave
# 5085033008                0                   0   1364 S Ridgeley Dr
# 5085032022                0                   0     1322 Hauser Blvd
# 5510005006                1                   0      6727 Drexel Ave
# 5089024002                0                   0    942 S Cochran Ave
#
#             MAIL DIFFERENT FROM SITE?  MAIL OUTSIDE CA?  TITLECO1  ASSDTOTAL  \
# PARCEL
# 5085010022                          0                 0         1    1157385
# 5085033008                          1                 0         0      57047
# 5085032022                          0                 0         1     651485
# 5510005006                          1                 0         0      85697
# 5089024002                          0                 0         0      62487
#
#             ASSDLAND  ASSDSTCT  ASSDOTHR  ...  NAME CHANGE  Other  \
# PARCEL                                    ...
# 5085010022    925908    231477         0  ...            0      0
# 5085033008     40994     16053         0  ...            0      0
# 5085032022    521193    130292         0  ...            0      0
# 5510005006     74539     11158         0  ...            0      0
# 5089024002     42013     20474         0  ...            0      0
#
#             PARTNERSHIP  PERSONAL REP  QUIT CLAIM  RE-RECORD  TAX DEED  \
# PARCEL
# 5085010022            0             0           0          0         0
# 5085033008            0             0           0          0         0
# 5085032022            0             0           0          0         0
# 5510005006            0             0           0          0         0
# 5089024002            0             0           0          0         0
#
#             TRUST TRANSFER  TRUSTEES  WARRANTY
# PARCEL
# 5085010022               0         0         0
# 5085033008               0         0         0
# 5085032022               0         0         0
# 5510005006               0         0         0
# 5089024002               0         0         0
#
# [5 rows x 57 columns]

# %%
Beverly_Grove_df = Beverly_Grove_df.dropna()

# %%
Beverly_Grove_df.dtypes
# Out:
# Owned by Trust?                int64
# Owned by Business?             int64
# SITEADDRESS                   object
# MAIL DIFFERENT FROM SITE?      int64
# MAIL OUTSIDE CA?               int64
# TITLECO1                       int64
# ASSDTOTAL                      int64
# ASSDLAND                       int64
# ASSDSTCT                       int64
# ASSDOTHR                       int64
# EXEMPTCD                       int64
# EXMPTAMT                       int64
# PCNTIMPD                       int64
# TAXAMT                       float64
# DOCDATE_YEAR                   int64
# MULTIPARCEL                    int64
# PRICE                          int64
# LENDER1                        int64
# LOANAMOUT1                     int64
# LOANTYPE1                      int64
# YEARBLT                        int64
# EFFYRBLT                     float64
# LOTSQFT                        int64
# TOTALSF                        int64
# GRGTYPE                        int64
# BLDGMAT                        int64
# TOTUNITS                       int64
# QUALCLAS                       int64
# BLDGCOND                       int64
# NOSTORY                      float64
# ROOFMAT                        int64
# FOUNDATN                       int64
# BEDROOMS                       int64
# BATHROOMS                      int64
# FAMILYRM                       int64
# DININGRM                       int64
# POOL                           int64
# PATIO                          int64
# FIREPLCE                       int64
# AIRMTHOD                       int64
# HEATMTHD                       int64
# VIEW                           int64
# Did it sell?                   int64
# GRANT DEED                     int64
# IN LIEU OF FORC                int64
# INTERSPOUSAL                   int64
# JOINT TENANT                   int64
# NAME CHANGE                    int64
# Other                          int64
# PARTNERSHIP                    int64
# PERSONAL REP                   int64
# QUIT CLAIM                     int64
# RE-RECORD                      int64
# TAX DEED                       int64
# TRUST TRANSFER                 int64
# TRUSTEES                       int64
# WARRANTY                       int64
# dtype: object

# %%
Beverly_Grove_df['TAXAMT'] = Beverly_Grove_df['TAXAMT'].astype(int)
Beverly_Grove_df['EFFYRBLT'] = Beverly_Grove_df['EFFYRBLT'].astype(int)

# %%
# Make sure our dataframe is only SFR's so exclude every property that has an '#' in its site address

Beverly_Grove_df = Beverly_Grove_df[~Beverly_Grove_df['SITEADDRESS'].str.contains('#')]
Beverly_Grove_df.head(3)
# Out:
#             Owned by Trust?  Owned by Business?          SITEADDRESS  \
# PARCEL
# 5085010022                0                   0  1030 S Dunsmuir Ave
# 5085033008                0                   0   1364 S Ridgeley Dr
# 5085032022                0                   0     1322 Hauser Blvd
#
#             MAIL DIFFERENT FROM SITE?  MAIL OUTSIDE CA?  TITLECO1  ASSDTOTAL  \
# PARCEL
# 5085010022                          0                 0         1    1157385
# 5085033008                          1                 0         0      57047
# 5085032022                          0                 0         1     651485
#
#             ASSDLAND  ASSDSTCT  ASSDOTHR  ...  NAME CHANGE  Other  \
# PARCEL                                    ...
# 5085010022    925908    231477         0  ...            0      0
# 5085033008     40994     16053         0  ...            0      0
# 5085032022    521193    130292         0  ...            0      0
#
#             PARTNERSHIP  PERSONAL REP  QUIT CLAIM  RE-RECORD  TAX DEED  \
# PARCEL
# 5085010022            0             0           0          0         0
# 5085033008            0             0           0          0         0
# 5085032022            0             0           0          0         0
#
#             TRUST TRANSFER  TRUSTEES  WARRANTY
# PARCEL
# 5085010022               0         0         0
# 5085033008               0         0         0
# 5085032022               0         0         0
#
# [3 rows x 57 columns]

# %%
# Now drop the SiteAddress column
Beverly_Grove_df.drop(['SITEADDRESS'], axis=1, inplace=True)

# %%
# check to see if it dropped.
Beverly_Grove_df.head(3)
# Out:
#             Owned by Trust?  Owned by Business?  MAIL DIFFERENT FROM SITE?  \
# PARCEL
# 5085010022                0                   0                          0
# 5085033008                0                   0                          1
# 5085032022                0                   0                          0
#
#             MAIL OUTSIDE CA?  TITLECO1  ASSDTOTAL  ASSDLAND  ASSDSTCT  \
# PARCEL
# 5085010022                 0         1    1157385    925908    231477
# 5085033008                 0         0      57047     40994     16053
# 5085032022                 0         1     651485    521193    130292
#
#             ASSDOTHR  EXEMPTCD  ...  NAME CHANGE  Other  PARTNERSHIP  \
# PARCEL                          ...
# 5085010022         0         0  ...            0      0            0
# 5085033008         0         0  ...            0      0            0
# 5085032022         0         1  ...            0      0            0
#
#             PERSONAL REP  QUIT CLAIM  RE-RECORD  TAX DEED  TRUST TRANSFER  \
# PARCEL
# 5085010022             0           0          0         0               0
# 5085033008             0           0          0         0               0
# 5085032022             0           0          0         0               0
#
#             TRUSTEES  WARRANTY
# PARCEL
# 5085010022         0         0
# 5085033008         0         0
# 5085032022         0         0
#
# [3 rows x 56 columns]

# %%
len(Beverly_Grove_df)
# Out:
# 4705

# %%
# Step 1: Create our X and y

y = Beverly_Grove_df['Did it sell?']
X = Beverly_Grove_df.drop(['Did it sell?'], 1)

# %%
APN = Beverly_Grove_df.index.values
APN
# Out:
# array([5085010022, 5085033008, 5085032022, ..., 5510018012, 5510017023,
#        5514001029])

# %%
# Split our data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
X_train.head(3)
# Out:
#             Owned by Trust?  Owned by Business?  MAIL DIFFERENT FROM SITE?  \
# PARCEL
# 5088017017                0                   0                          0
# 5089020010                0                   0                          0
# 5088016028                1                   0                          0
#
#             MAIL OUTSIDE CA?  TITLECO1  ASSDTOTAL  ASSDLAND  ASSDSTCT  \
# PARCEL
# 5088017017                 0         1     340000    136000    204000
# 5089020010                 0         0     218091    106556    111535
# 5088016028                 0         1     195815     49267    146548
#
#             ASSDOTHR  EXEMPTCD  ...  NAME CHANGE  Other  PARTNERSHIP  \
# PARCEL                          ...
# 5088017017         0         1  ...            0      0            0
# 5089020010         0         1  ...            0      0            0
# 5088016028         0         1  ...            0      0            0
#
#             PERSONAL REP  QUIT CLAIM  RE-RECORD  TAX DEED  TRUST TRANSFER  \
# PARCEL
# 5088017017             0           0          0         0               0
# 5089020010             0           0          0         0               0
# 5088016028             0           0          0         0               0
#
#             TRUSTEES  WARRANTY
# PARCEL
# 5088017017         0         0
# 5089020010         0         0
# 5088016028         0         0
#
# [3 rows x 55 columns]

# %%
# Scale our data

# Create the StandardScaler instance
scaler = StandardScaler()

# Fit our scaler, named 'scaler' to our data, which produces a new StandardScaler object
# which we call 'X_scaler'
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled_APN = []

# %%
for index, parcel in enumerate(X_train.index.values):
     X_train_scaled_APN.append(np.insert(X_train_scaled[index], 0, [parcel]))

# %%
# Create the learning model

log_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=300,
                                random_state=78,
                                class_weight="balanced")

# Train the model
log_classifier.fit(X_train_scaled, y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test_scaled)

print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.592

# %%
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test, "PARCEL": y_test.index.values}).reset_index(drop=True)
results.sample(20)
# Out:
#       Prediction  Actual      PARCEL
# 1026           0       0  5510013025
# 690            1       0  5085004005
# 894            0       0  5088009006
# 1000           1       0  5085007005
# 468            1       1  5526021012
# 735            1       0  5510019025
# 267            1       1  5510017029
# 266            0       0  5085011009
# 975            0       0  5510018007
# 230            1       0  5511006002
# 769            0       0  5086020002
# 778            0       0  5512017024
# 640            1       0  5514002049
# 845            0       0  5510001005
# 783            0       0  5085034018
# 271            1       0  5511003016
# 840            0       0  5526027023
# 249            1       0  5514003030
# 1095           1       0  4334023042
# 974            0       0  5526037002

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=150, activation="relu", input_dim=55))
nn_model.add(tf.keras.layers.Dense(units=150, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=150, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=150, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=150, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=150, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=150, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=200)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/20
# 111/111 [==============================] - 1s 2ms/step - loss: 0.3312 - accuracy: 0.9053
# Epoch 2/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.9307
# Epoch 3/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.9274
# Epoch 4/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9329
# Epoch 5/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.2229 - accuracy: 0.9273
# Epoch 6/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.9373
# Epoch 7/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.1695 - accuracy: 0.9392
# Epoch 8/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.1776 - accuracy: 0.9299
# Epoch 9/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.1440 - accuracy: 0.9493
# Epoch 10/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9573
# Epoch 11/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9583
# Epoch 12/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9577
# Epoch 13/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9659
# Epoch 14/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0884 - accuracy: 0.9664
# Epoch 15/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9727
# Epoch 16/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0574 - accuracy: 0.9766
# Epoch 17/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 0.9790
# Epoch 18/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9812
# Epoch 19/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 0.9808
# Epoch 20/20
# 111/111 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9818
# 37/37 - 0s - loss: 0.7969 - accuracy: 0.8895
# Loss: 0.7968716025352478, Accuracy: 0.889549732208252

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[666, 430],
#        [ 50,  31]])

# %%
model_accuracy
# Out:
# 0.9226847887039185

# %%
from sklearn.metrics import balanced_accuracy_score

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.4951901414796792

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)
# Out:
# 0.1143911439114391

# %%
# print out the classification report

from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-53-a47f9acd08ed> in <module>
#       1 # print out the classification report
#       2
# ----> 3 from imblearn.metrics import classification_report_imbalanced
#       4 print(classification_report_imbalanced(y_test, y_pred))
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
#y_pred = nn_model(X_test_scaled)
#predictions = fit_model.eval(feed_dict = {x:X_test_scaled})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-b299282eabc5> in <module>
#       1 #y_pred = nn_model(X_test_scaled)
# ----> 2 predictions = fit_model.eval(feed_dict = {x:X_test_scaled})
#
# AttributeError: 'History' object has no attribute 'eval'

# %%
# Convert our new, fitted model into a dataframe

new_fit_model_df = pd.DataFrame(X_train_scaled)
new_fit_model_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.618859 -0.185205 -0.522673 -0.147378  0.740761 -0.644949 -0.865631
# 1 -0.618859 -0.185205 -0.522673 -0.147378 -1.349963 -0.848467 -0.934399
# 2  1.615876 -0.185205 -0.522673 -0.147378  0.740761 -0.885655 -1.068201
# 3 -0.618859 -0.185205 -0.522673 -0.147378  0.740761 -0.064153 -0.298649
# 4  1.615876 -0.185205 -0.522673 -0.147378 -1.349963 -0.584741 -0.773096
#
#          7        8         9   ...        45        46        47   48  \
# 0 -0.071031 -0.01959  0.923548  ... -0.016838 -0.190861 -0.016838  0.0
# 1 -0.489487 -0.01959  0.923548  ... -0.016838 -0.190861 -0.016838  0.0
# 2 -0.331034 -0.01959  0.923548  ... -0.016838 -0.190861 -0.016838  0.0
# 3  0.404786 -0.01959 -1.082781  ... -0.016838 -0.190861 -0.016838  0.0
# 4 -0.087120 -0.01959  0.923548  ... -0.016838 -0.190861 -0.016838  0.0
#
#          49        50   51       52        53        54
# 0 -0.428364 -0.029173  0.0 -0.28672 -0.029173 -0.033691
# 1 -0.428364 -0.029173  0.0 -0.28672 -0.029173 -0.033691
# 2 -0.428364 -0.029173  0.0 -0.28672 -0.029173 -0.033691
# 3 -0.428364 -0.029173  0.0 -0.28672 -0.029173 -0.033691
# 4 -0.428364 -0.029173  0.0 -0.28672 -0.029173 -0.033691
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Now try a Neural Net with resampled data
